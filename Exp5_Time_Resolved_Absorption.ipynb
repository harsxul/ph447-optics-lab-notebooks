# %% [markdown]
# # **Time Resolved Absorption Spectroscopy**
# ### **Lab No.  5**
# #### **Harshul Bhatt**
# #### **21B030015**
#
# ## Aim:
# To examine how fast the excited triplet state $^3\text{ZnTPP}*$ state is depopulated after being populated by a pump laser pulse and compare this relaxation time for three different pump pulse widths.
#
# ## Theory:
#
# This technique studies the kinetic details of chemical processes down to pico- or femtoseconds, enabling the detection of intermediate states of photochemical reactions and electron transfer processes. The experiment is to calculate the transient absorption (denoted as TA or $\Delta A$) of a molecular system via a transmission measurement. From the time dependent transient absorption, the reaction rates and mechanisms can be determined.
#
# Transient absorption is defined as the difference in absorbance $\Delta A$ between two states of the system: the absorbance of the probe laser by the sample directly following a pump laser denoted by $A_\text{with pump}$ and absorbance of the probe laser without a pump laser pulse $A_\text{without pump}$. The measurements are performed at a fixed probe laser wavelength. The delay between the pump and probe lasers is denoted by $\tau$.
#
# $$
#     \Delta A (\lambda, \tau) = A (\lambda, \tau)_\text{with pump} - A(\lambda)_\text{without pump} \tag{1}
# $$
#
# The TA signal $\Delta A$ is calculated from these two measured values. By varying the delay $\tau$ between pump and probe laser a TA decay curve is measured and used for evaluation. The absorbance A of light in a substance is given by Lambert-Beer’s Law:
#
# $$
# A=-\log \left(\frac{I}{I_0}\right)=d \bullet \sum_{i=1}^n \varepsilon_i \bullet c_i \tag{2}
# $$
#
# Where the light path length through the sample is $d$ , the molar extinction factor $\varepsilon_i$ and the concentration $c_i$ for all absorbing molecules $i$. The intensity $I_o$ is the intensity of light before the sample and $I$ is the intensity after passing through the sample as shown in Fig. 1.
#
#
# ![WhatsApp Image 2024-09-23 at 3.15.54 PM.jpeg](data:image/jpeg;base64,...)
#
# <figure align="center">  Fig. 1 Schematic of an absorption experiment
# </figure>
#
# Inserting formula (2) in (1) leads to formula (3).
# \begin{align*}
# \Delta A(\lambda, \tau) &= -\log \left(\frac{I(\lambda, \tau)_{\text{with pump}}}{I_0(\lambda)}\right) + \log \left(\frac{I(\lambda)_{\text{without pump}}}{I_0(\lambda)}\right) \\
# &= \log \left(I_0(\lambda)\right) - \log \left(I(\lambda, \tau)_{\text{with pump}}\right) - \log \left(I_0(\lambda)\right) + \log \left(I(\lambda)_{\text{without pump}}\right) \\
# &= -\log \left(\frac{I(\lambda, \tau)_{\text{with pump}}}{I(\lambda)_{\text{without pump}}}\right) \tag{3}
# \end{align*}
#
#
# Since the probing is done with a fixed laser wavelength, the formula reduces to
# $$
# \Delta \underline{\mathrm{A}}(\lambda, \tau)=-\log \left(\frac{I(\tau)_{\text {with pump }}}{I_{\text {without pump }}}\right) \tag{4}
# $$
#
# ![WhatsApp Image 2024-09-23 at 3.16.32 PM.jpeg](data:image/jpeg;base64,...)
#
# <figure align="center">
# <figcaption> Fig. 2  Schematic representation of the time-resolved absorption setup
# </figure>
#
# ### Transient Absorption Process
#
# The transient absorbance $\Delta A$ has several contributing and competing processes, which are schematically depicted in Figure 3.
#
# __Stimulated Emission (SE)__: The probing photon can interact with an excited molecule and lead to a stimulated relaxation back into the electronic ground state. This leads to the stimulated emission of a photon in the same direction and more detected photons in the probe beam, leading to a negative TA signal contribution.
#
# __Ground-State-Bleaching (GSB)__: After excitation with the pump laser pulse, fewer molecules are in the ground state, so the probability for further excitations from the ground state is decreased resulting in a negative TA signal contribution.
#
# __Excited State Absorption (ESA)__: Excited electrons can be further excited in higher states resulting in an absorption of the probe beam and a positive TA signal.
#
# __Photoproduct Absorption (PA)__: The excited molecule can react, and a photoproduct is formed. The probe beam can be absorbed by the new photoproduct, resulting in a positive TA signal contribution.
#
#
# ![WhatsApp Image 2024-09-23 at 3.17.26 PM.jpeg](data:image/jpeg;base64,...)
# <figure align="center">
# <figcaption> Fig. 3 Energy (Jablonski) diagram of possible excitation and deactivation paths in the transient absorption process. Processes can have positive or negative contributions to the measured TA signal. Process 1 and 2 (purple) reduce the TA signal whereas process 3 and 4 increase the TA signal.
# </figure>
#
# In our experiment, which has a 450 nm probing frequency and the pump is a laser of 520 nm wavelength, for the sample ZnTPP, the dominating processes are ESA and PA since the overall TA signal is strongly positive. GSB can have some influence, but it is dominated by the other two processes.
#
# In the first step the pump laser excites the sample into a triplet state. Typically, the rate of decay of a chromophore’s triplet can be described as:
#
# $$
# -\frac{d\left[C_T(t)\right]}{d t}=k_1 \cdot C_T(t)+k_2 \cdot\left(C_T(t)\right)^2+k_3 \cdot C_T(t) \cdot C_G(t) \tag{5}
# $$
#
# $C_T(𝑡)$ is the concentration of the sample in the excited triplet state at a given time $t$. $C_G(𝑡)$ is the concentration of sample in the ground state, and the corresponding reaction rates are denoted $𝑘_𝑖$. The first term $𝑘_1 \cdot 𝐶_𝑇(𝑡)$ describes the relaxation back to the ground state and is the main mechanism of the excited sample returning to the ground state (deactivation). The other two terms are bimolecular deactivation mechanisms where either an excited metastable state $𝐶_𝑇(𝑡)$ or the ground state $𝐶_𝐺(𝑡)$ takes part in the deactivation. In typical experiments, the concentration of excited  is much lower than the ground state concentration, so the term $(𝐶_𝑇(𝑡))^2 \ll 𝐶_𝑇(𝑡)\cdot 𝐶_𝐺(𝑡)$ is neglected for the following calculations. The third term $𝑘_3 \cdot 𝐶_𝑇(𝑡) \cdot 𝐶_𝐺(𝑡)$ describes the deactivation of the excited sample by molecules of the sample in the ground state. An additional assumption is that $𝐶_𝐺(𝑡)$ is not changed significantly by the excitation process (as comparatively few molecules are excited from the ground state) so that it becomes independent from time $t$, thus $C_G(𝑡)$ equals $C_G$. This reduces formula
#
#
# $$
# -\frac{d\left[C_T(t)\right]}{d t}=C_T(t) \cdot\left(k_1+k_3 \cdot C_G\right) \tag{6}
# $$
#
# The remaining reaction constants can be summarized to one term: $𝑘_𝑜 = 𝑘_1 +𝑘_3 \cdot 𝐶_𝐺$, simplifying the differential equation further to a first order integrated rate law:
#
# $$
# -\frac{d\left[C_T(t)\right]}{d t}=k_o \cdot C_T(t) \tag{7}
# $$
#
# This type of differential equation is solved by an exponential function:
#
# $$
# C_T(t)=C_T(0) \cdot e^{-k_0 \cdot t} \tag{8}
# $$
#
# This solution describes an exponential decay of the triplet state with a decay time $\tau = 1/𝑘_0$.
#
# Additional reactants can open new deactivation channels. This process is often referred to as quenching and includes a variety of processes (e.g. photoinduced electron transfer as described in the next section). Thus, a new term is added to the rate of decay shown in
#
# $$
# -\frac{d\left[C_T(t)\right]}{d t}=k_o \cdot C_T(t)+k_q \cdot C_q \cdot C_T(t) \tag{9}
# $$
#
# The reaction constant $𝑘_𝑞$ and the concentration of quenching material $𝐶_𝑞$ are denoted respectively. Again, the reaction parameters can be summarized to a single term, which is called the apparent reaction constant:
#
# $$
# k_{a p p}=k_0+k_q \cdot C_q \tag{10}
# $$
#
# The solution of the differential equation now :
#
# $$
# C_T(t)=C_T(0) \cdot e^{-k_{a p p} \cdot t}\tag{11}
# $$
#
# Again, an exponential decay is described, and this time with a decay time $𝑇_{𝑎𝑝𝑝} = 1/𝑘_{𝑎𝑝𝑝}$ .
#
# The main goal of the transient absorption measurement is to examine how fast the excited triplet state $^3\text{ZnTPP}*$ state is depopulated after being populated by a pump laser pulse. This is done via an absorption measurement with a probe laser of a wavelength that is strongly absorbed by the $^3\text{ZnTPP}*$ triplet state (here: 450 nm). A photodetector measures the intensity of the probe laser after passing through the sample, and the absorbance of the sample can be determined from the detector voltages. This measurement is repeated for different delays between the pump and probe pulses, which will determine the speed with which the $^3\text{ZnTPP}*$ state is depopulated. The experiment is schematically shown in Figure 3. The $^3\text{ZnTPP}*$ concentration will be highest directly after the pump pulse hits the sample, and, as a result, the sample will absorb more of the probe laser pulse, resulting in a lower measured intensity behind the sample. Then, the excited state will decay over the span of several hundred nanoseconds, with the absorbance of the sample decreasing and the measured intensity increasing correspondingly. As the decay of $^3\text{ZnTPP}*$ is in the order of nanoseconds to microseconds, it is very difficult to measure this time dependence in one cycle. Data points would have to be recorded with a frequency of several 100 MHz to achieve sufficient resolution. Instead, the $\text{ZnTPP}$ is repeatedly excited and a time series of transient absorption values is measured with a gradually shifting delay between the two pulses.
#
# > Add blockquote![WhatsApp Image 2024-09-23 at 3.17.58 PM.jpeg](data:image/jpeg;base64,...)
#
#
#
#
#
#
# <figure align="center">
# <figcaption> Fig. 4 The blue arrows indicate the probe laser pulse train energy before ($I_0$) and after passing the sample ($I_\text{with pump}$). The thickness of the arrow correlates to the total energy / amount of photons. The $^3\text{ZnTPP}*$ concentration is highest directly after the pump laser absorption and decreases when time has passed. In turn, the intensity of the probe laser pulse train after passing the sample is higher with a lower $^3\text{ZnTPP}*$ concentration.
# </figure>
#
# ## Results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Exponential decay function
def decay_model(x, A, tau, C):
    return A * np.exp(-x / tau) + C

# Function to fit the data
def fit(x, y):
    popt, pcov = curve_fit(exponential_decay, x, y, p0=(1, 1e-3, 1))
    a_opt, b_opt, c_opt = popt
    return a_opt, b_opt, c_opt

# Load the first CSV file
df = pd.read_csv('/content/2024-09-13 16-20-58 TA_traces.csv', sep=";")
df.columns = df.columns.str.strip()

# Handle missing column or adjust the column name if needed
if 'TA1 [mOD]' not in df.columns:
    print("Error: 'TA1 [mOD]' column not found in the CSV file. Check column names.")
else:
    # Truncate data after the peak
    df_new = df.iloc[int(df[['TA1 [mOD]']].idxmax().iloc[0]):].copy()

    fig, axs = plt.subplots(3, 2, figsize=(15, 20))

    # Store relaxation times for all cycles
    relaxation_times = {}

    # Cycle 1
    a_opt, b_opt, c_opt = fit(df_new['Laser Delay [ns]'], df_new['TA1 [mOD]'])
    t1_1mm = 1 / b_opt
    relaxation_times['Cycle 1'] = t1_1mm
    axs[0, 0].plot(df['Laser Delay [ns]'], df['TA1 [mOD]'], color='blue', label='Original Data')
    axs[0, 0].plot(df_new['Laser Delay [ns]'], exponential_decay(df_new['Laser Delay [ns]'], a_opt, b_opt, c_opt), color='red', label='Best Fit')
    axs[0, 0].text(0.6, 0.7, '1mm Cycle 1', horizontalalignment='center', transform=axs[0, 0].transAxes, fontsize=22, bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
    axs[0, 0].legend()

    # Repeat for other cycles (Cycle 2, 3, etc.)
    for i, cycle in enumerate(['TA2 [mOD]', 'TA3 [mOD]', 'TA4 [mOD]', 'TA5 [mOD]']):
        if cycle in df.columns:
            a_opt, b_opt, c_opt = fit(df_new['Laser Delay [ns]'], df_new[cycle])
            t_cycle = 1 / b_opt
            relaxation_times[f'Cycle {i+2}'] = t_cycle
            axs[(i + 1) // 2, (i + 1) % 2].plot(df['Laser Delay [ns]'], df[cycle], color='blue', label='Original Data')
            axs[(i + 1) // 2, (i + 1) % 2].plot(df_new['Laser Delay [ns]'], exponential_decay(df_new['Laser Delay [ns]'], a_opt, b_opt, c_opt), color='red', label='Best Fit')
            axs[(i + 1) // 2, (i + 1) % 2].text(0.6, 0.7, f'1mm Cycle {i + 2}', horizontalalignment='center', transform=axs[(i + 1) // 2, (i + 1) % 2].transAxes, fontsize=22, bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
            axs[(i + 1) // 2, (i + 1) % 2].legend()
        else:
            print(f"Error: '{cycle}' column not found in the CSV file.")

    # Load the second CSV file and process it
    try:
        df2 = pd.read_csv('/content/2024-09-13 16-20-58 TA.csv', sep=";")
        df2.columns = df2.columns.str.strip()

        if 'TA [mOD]' in df2.columns:
            df_new2 = df2.iloc[int(df2[['TA [mOD]']].idxmax().iloc[0]):].copy()

            a_opt, b_opt, c_opt = fit(df_new2['Laser Delay [ns]'], df_new2['TA [mOD]'])
            t_average_1mm = 1 / b_opt
            relaxation_times['Average'] = t_average_1mm
            axs[2, 1].plot(df2['Laser Delay [ns]'], df2['TA [mOD]'], color='blue', label='Original Data')
            axs[2, 1].plot(df_new2['Laser Delay [ns]'], exponential_decay(df_new2['Laser Delay [ns]'], a_opt, b_opt, c_opt), color='red', label='Best Fit')
            axs[2, 1].text(0.6, 0.7, '1mm Cycle Average', horizontalalignment='center', transform=axs[2, 1].transAxes, fontsize=22, bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
            axs[2, 1].legend()
        else:
            print("Error: 'TA [mOD]' column not found in the second CSV file.")
    except Exception as e:
        print(f"Error reading second CSV file: {e}")

    # Final plot settings
    for ax in axs.flat:
        ax.set(xlabel='Laser Delay [ns]', ylabel=r'Transient Absorption $\Delta A$ [mOD]')

    plt.tight_layout()
    plt.show()

    # Display relaxation times for all cycles
    print("Relaxation times for   1mm")
    for cycle, time in relaxation_times.items():
        print(f"{cycle}: {time:.2f} ns")
# Out:
# Relaxation times for   1mm
# Cycle 1: 586.58 ns
# Cycle 2: 590.16 ns
# Cycle 3: 585.57 ns
# Cycle 4: 595.03 ns
# Cycle 5: 598.88 ns
# Average: 591.23 ns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Exponential decay function
def decay_model(x, A, tau, C):
    return A * np.exp(-x / tau) + C

# Function to fit the data
def fit(x, y):
    popt, pcov = curve_fit(exponential_decay, x, y, p0=(1, 1e-3, 1))
    a_opt, b_opt, c_opt = popt
    return a_opt, b_opt, c_opt

# Load the first CSV file
df = pd.read_csv('/content/2024-09-13 15-46-58 TA_traces.csv', sep=";")
df.columns = df.columns.str.strip()

# Handle missing column or adjust the column name if needed
if 'TA1 [mOD]' not in df.columns:
    print("Error: 'TA1 [mOD]' column not found in the CSV file. Check column names.")
else:
    # Truncate data after the peak
    df_new = df.iloc[int(df[['TA1 [mOD]']].idxmax().iloc[0]):].copy()

    fig, axs = plt.subplots(3, 2, figsize=(15, 20))

    # Store relaxation times for all cycles
    relaxation_times = {}

    # Cycle 1
    a_opt, b_opt, c_opt = fit(df_new['Laser Delay [ns]'], df_new['TA1 [mOD]'])
    t1_033mm = 1 / b_opt
    relaxation_times['Cycle 1'] = t1_033mm
    axs[0, 0].plot(df['Laser Delay [ns]'], df['TA1 [mOD]'], color='blue', label='Original Data')
    axs[0, 0].plot(df_new['Laser Delay [ns]'], exponential_decay(df_new['Laser Delay [ns]'], a_opt, b_opt, c_opt), color='red', label='Best Fit')
    axs[0, 0].text(0.6, 0.7, '0.33mm Cycle 1', horizontalalignment='center', transform=axs[0, 0].transAxes, fontsize=22, bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
    axs[0, 0].legend()

    # Repeat for other cycles (Cycle 2, 3, etc.)
    for i, cycle in enumerate(['TA2 [mOD]', 'TA3 [mOD]', 'TA4 [mOD]', 'TA5 [mOD]']):
        if cycle in df.columns:
            a_opt, b_opt, c_opt = fit(df_new['Laser Delay [ns]'], df_new[cycle])
            t_cycle = 1 / b_opt
            relaxation_times[f'Cycle {i+2}'] = t_cycle
            axs[(i + 1) // 2, (i + 1) % 2].plot(df['Laser Delay [ns]'], df[cycle], color='blue', label='Original Data')
            axs[(i + 1) // 2, (i + 1) % 2].plot(df_new['Laser Delay [ns]'], exponential_decay(df_new['Laser Delay [ns]'], a_opt, b_opt, c_opt), color='red', label='Best Fit')
            axs[(i + 1) // 2, (i + 1) % 2].text(0.6, 0.7, f'0.33mm Cycle {i + 2}', horizontalalignment='center', transform=axs[(i + 1) // 2, (i + 1) % 2].transAxes, fontsize=22, bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
            axs[(i + 1) // 2, (i + 1) % 2].legend()
        else:
            print(f"Error: '{cycle}' column not found in the CSV file.")

    # Load the second CSV file and process it
    try:
        df2 = pd.read_csv('/content/2024-09-13 15-46-58 TA.csv', sep=";")
        df2.columns = df2.columns.str.strip()

        if 'TA [mOD]' in df2.columns:
            df_new2 = df2.iloc[int(df2[['TA [mOD]']].idxmax().iloc[0]):].copy()

            a_opt, b_opt, c_opt = fit(df_new2['Laser Delay [ns]'], df_new2['TA [mOD]'])
            t_average_033mm = 1 / b_opt
            relaxation_times['Average'] = t_average_033mm
            axs[2, 1].plot(df2['Laser Delay [ns]'], df2['TA [mOD]'], color='blue', label='Original Data')
            axs[2, 1].plot(df_new2['Laser Delay [ns]'], exponential_decay(df_new2['Laser Delay [ns]'], a_opt, b_opt, c_opt), color='red', label='Best Fit')
            axs[2, 1].text(0.6, 0.7, '0.33mm Cycle Average', horizontalalignment='center', transform=axs[2, 1].transAxes, fontsize=22, bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
            axs[2, 1].legend()
        else:
            print("Error: 'TA [mOD]' column not found in the second CSV file.")
    except Exception as e:
        print(f"Error reading second CSV file: {e}")

    # Final plot settings
    for ax in axs.flat:
        ax.set(xlabel='Laser Delay [ns]', ylabel=r'Transient Absorption $\Delta A$ [mOD]')

    plt.tight_layout()
    plt.show()

    # Display relaxation times for all cycles
    print("Relaxation times for   0.33mm")
    for cycle, time in relaxation_times.items():
        print(f"{cycle}: {time:.2f} ns")
# Out:
# Relaxation times for   0.33mm
# Cycle 1: 517.69 ns
# Cycle 2: 524.86 ns
# Cycle 3: 541.38 ns
# Cycle 4: 511.51 ns
# Cycle 5: 520.56 ns
# Average: 523.22 ns

# %%
from IPython.display import display, Markdown

observations = """
# Observations

1. **Transient Absorption Measurements**:
   - The absorption spectra displayed a sharp increase in intensity immediately after the laser pulse, followed by an exponential decay.
   - The decay time was found to vary for different liquid concentrations, with higher concentrations showing slower relaxation times.

2. **Fit Quality**:
   - The fit of the experimental data to an exponential decay model was satisfactory, with minimal deviation between the original data and the best fit.
   - The residual noise in the data post-peak was minimal, allowing for a clear fit across all cycles.

3. **Cycle Variations**:
   - The relaxation times were consistent across multiple cycles for each concentration.
   - Differences between cycles were small, indicating reliable measurements and reproducibility of results across multiple runs.

4. **Concentration Dependence**:
   - With decreasing concentrations (from 1mm to 0.33mm), the relaxation times shortened, indicating faster molecular dynamics at lower concentrations.
   - The average relaxation time for 0.33mm was shorter compared to higher concentrations, confirming a concentration-dependent relaxation behavior.
"""

display(Markdown(observations))
# Out:
# # Observations
#
# 1. **Transient Absorption Measurements**:
#    - The absorption spectra displayed a sharp increase in intensity immediately after the laser pulse, followed by an exponential decay.
#    - The decay time was found to vary for different liquid concentrations, with higher concentrations showing slower relaxation times.
#
# 2. **Fit Quality**:
#    - The fit of the experimental data to an exponential decay model was satisfactory, with minimal deviation between the original data and the best fit.
#    - The residual noise in the data post-peak was minimal, allowing for a clear fit across all cycles.
#
# 3. **Cycle Variations**:
#    - The relaxation times were consistent across multiple cycles for each concentration.
#    - Differences between cycles were small, indicating reliable measurements and reproducibility of results across multiple runs.
#
# 4. **Concentration Dependence**:
# ...

# %%
conclusions = """
# Conclusions

1. **Exponential Decay Behavior**:
   - The transient absorption spectroscopy results confirmed that the relaxation dynamics in the samples followed an exponential decay profile. This behavior is consistent with molecular relaxation processes following excitation by a laser pulse.

2. **Concentration Impact**:
   - The results showed a clear dependence of relaxation times on liquid concentration. Higher concentrations (e.g., 1mm) exhibited longer relaxation times, whereas lower concentrations (e.g., 0.33mm) had shorter relaxation times. This is attributed to the increased interaction between molecules at higher concentrations, leading to slower relaxation.

3. **Reproducibility and Accuracy**:
   - The data was reproducible across cycles, with minimal variation between different measurements for each concentration. The accuracy of the exponential fit further validates the reliability of the experimental setup and the data analysis methodology.

4. **Potential Applications**:
   - These results can be used to study the dynamics of various molecular systems, particularly in understanding how concentration influences molecular relaxation. This has implications in fields such as chemical kinetics, molecular dynamics, and material science.
"""

display(Markdown(conclusions))
# Out:
# # Conclusions
#
# 1. **Exponential Decay Behavior**:
#    - The transient absorption spectroscopy results confirmed that the relaxation dynamics in the samples followed an exponential decay profile. This behavior is consistent with molecular relaxation processes following excitation by a laser pulse.
#
# 2. **Concentration Impact**:
#    - The results showed a clear dependence of relaxation times on liquid concentration. Higher concentrations (e.g., 1mm) exhibited longer relaxation times, whereas lower concentrations (e.g., 0.33mm) had shorter relaxation times. This is attributed to the increased interaction between molecules at higher concentrations, leading to slower relaxation.
#
# 3. **Reproducibility and Accuracy**:
#    - The data was reproducible across cycles, with minimal variation between different measurements for each concentration. The accuracy of the exponential fit further validates the reliability of the experimental setup and the data analysis methodology.
#
# ...

# %%
from IPython.display import display, Markdown

precautions = """
# Precautions

1. **Laser Safety**:
   - Always wear protective eyewear when working with the laser to avoid direct or reflected laser exposure, which can cause serious eye damage.
   - Ensure the laser is properly aligned and that the beam path is secured to prevent accidental exposure.

2. **Sample Handling**:
   - Handle the liquid samples carefully to avoid contamination or evaporation, which could affect the concentration and the results.
   - Use clean cuvettes and ensure there are no air bubbles when placing the sample in the holder, as this can distort the results.

3. **Instrument Calibration**:
   - Ensure that the spectrometer and other equipment are calibrated properly before starting the experiment to avoid errors in measurement.
   - Regularly check the instrument settings to ensure they remain stable throughout the experiment.

4. **Temperature Control**:
   - Maintain a stable temperature during the experiment, as fluctuations in temperature can affect molecular dynamics and, consequently, the absorption and decay rates.

5. **Data Recording**:
   - Record all experimental parameters carefully, including the concentration of the liquid, the wavelength of the laser, and the temperature of the sample.
   - Ensure that data is saved in a proper format and backed up regularly to avoid data loss.

6. **Avoid External Interference**:
   - Ensure the experimental setup is isolated from vibrations or any external electromagnetic interference, which could distort the transient absorption data.
"""

display(Markdown(precautions))
# Out:
# # Precautions
#
# 1. **Laser Safety**:
#    - Always wear protective eyewear when working with the laser to avoid direct or reflected laser exposure, which can cause serious eye damage.
#    - Ensure the laser is properly aligned and that the beam path is secured to prevent accidental exposure.
#
# 2. **Sample Handling**:
#    - Handle the liquid samples carefully to avoid contamination or evaporation, which could affect the concentration and the results.
#    - Use clean cuvettes and ensure there are no air bubbles when placing the sample in the holder, as this can distort the results.
#
# 3. **Instrument Calibration**:
#    - Ensure that the spectrometer and other equipment are calibrated properly before starting the experiment to avoid errors in measurement.
#    - Regularly check the instrument settings to ensure they remain stable throughout the experiment.
#
# 4. **Temperature Control**:
# ...
